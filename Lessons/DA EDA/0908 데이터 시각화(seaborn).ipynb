# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

x = [10,20,30]   # x[0] = 10, x[1] = 20, x[2] = 30  ======> (0,10) ,(1,20), (2,30)
plt.plot(x)

# %%
x = np.arange(10)
y = x**2
plt.plot(x,y)

# %%
x = np.arange(10)
y = x**2
plt.plot(x,y,'r.')

# %%
x = np.arange(10)
plt.plot(x,x*2,'b-')
plt.plot(x,x**2,'r--')
plt.plot(x,x**3,'g^')
plt.title('한글')
# Out:
# Text(0.5, 1.0, '한글')
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.rcParams["font.family"] = 'NanumGothic'
x = np.arange(10)
plt.plot(x,x*2,'b-')
plt.plot(x,x**2,'r--')
plt.plot(x,x**3,'g^')
plt.title('한글')
# Out:
# Text(0.5, 1.0, '한글')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

sns.set_style('whitegrid')

tips = sns.load_dataset('tips')
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style('whitegrid')

plt.figure(figsize=(8,6))
sns.boxplot(x=tips['total_bill'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='day',y='tip',data=tips, hue = 'smoker', palette='Set3')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,6))
sns.swarmplot(x='day',y='total_bill',data=tips,color='.5')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='.25')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.set_style('darkgrid')
sns.lmplot(x='total_bill',y='tip',data=tips,height=7)
plt.show()

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights = flights.pivot('month','year','passengers')
flights.head()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %%
plt.figure(figsize=(10,8))
sns.heatmap(flights)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(flights, annot=True, fmt = 'd')
plt.show()

# %%
sns.set(style='ticks')
iris = sns.load_dataset('iris')
sns.pairplot(iris)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(iris, hue = 'species')
plt.show()

# %%
sns.pairplot(iris, vars = ['sepal_width','sepal_length'])
plt.show()

# %%
sns.pairplot(iris, x_vars = ['sepal_width','sepal_length'], y_vars = ['petal_width','petal_length'])
plt.show()

# %%
cond = apt_price['구'].isin('강남구,서초구'.split(','))
apt_price[cond].pivot_table()
