# %% [markdown]
# # STEP 0. Import

# %%
import os
import zipfile
import urllib.request
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# # STEP 1. Load Dataset

# %%
# 코드를 실행하세요.
# 데이터 다운로드 및 압축 풀기
url = 'https://storage.googleapis.com/download.tensorflow.org/data/rps.zip'
urllib.request.urlretrieve(url, 'rps.zip')
local_zip = 'rps.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('data/')
zip_ref.close()

# %%
# 코드를 실행하세요.
# data/rps 경로의 파일 확인
os.listdir('data/rps/')
# Out:
# ['rock', 'paper', 'scissors']

# %%
# 코드를 실행하세요.
# scissors 폴더의 첫 번째 데이터 경로
sample_data_dir = f"data/rps/scissors/{os.listdir('data/rps/scissors')[0]}"
sample_data_dir
# Out:
# 'data/rps/scissors/scissors03-030.png'

# %%
# 코드를 실행하세요.
# sample_data를 로드하세요.
from tensorflow.keras.preprocessing.image import load_img, img_to_array
sample_data = load_img(sample_data_dir, target_size=(150, 150))
sample_data = img_to_array(sample_data) / 255

# sample_data의 shape와 첫 번째 픽셀을 출력하세요.
sample_data.shape, sample_data[0, 0, :]
# Out:
# ((150, 150, 3), array([0.99607843, 0.99607843, 0.99607843], dtype=float32))

# %%
# sample_data를 시각화하세요.
plt.imshow(sample_data)
plt.show()

# %%
# 코드를 실행하세요.
# 'scissors', 'rock', 'paper'의 각 이미지 3개씩 subplot 하세요.
from tensorflow.keras.preprocessing.image import load_img, img_to_array

plt.figure(figsize = (9,9))

for i, c in enumerate(['scissors', 'rock', 'paper']) :
    files = os.listdir(f'data/rps/{c}')[:3]
    for j, file in enumerate(files) :
        plt.subplot(3,3, 3*i + j + 1)

        # 이미지 로드
        image = load_img(f'data/rps/{c}/{file}', target_size=(150, 150))
        image = img_to_array(image) / 255
        
        # plot
        plt.imshow(image)
        plt.axis(False)
        plt.title(c)
plt.show()

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# # STEP 2. 전처리 (ImageDataGenerator)
# `ImageDataGenerator`를 정의합니다.
#
# 다음의 옵션 값들로 Image Aumentation(이미지 변형) 옵션을 적절히 조절해 주세요
#
# * `rescale`: 이미지의 픽셀 값을 조정
# * `rotation_range`: 이미지 회전
# * `width_shift_range`: 가로 방향으로 이동
# * `height_shift_range`: 세로 방향으로 이동
# * `shear_range`: 이미지 굴절
# * `zoom_range`: 이미지 확대
# * `horizontal_flip`: 횡 방향으로 이미지 반전
# * `fill_mode`: 이미지를 이동이나 굴절시켰을 때 빈 픽셀 값에 대하여 값을 채우는 방식
# * `validation_split`: validation set의 구성 비율

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# 나머지 옵션은 자유롭게 사용하고 validation_split은 0.2로 지정하세요.
training_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip= True,
    validation_split = 0.2,
    fill_mode='nearest'
)

# %% [markdown]
# ImageDataGenerator를 잘 만들어 주었다면, `flow_from_directory`로 이미지를 어떻게 공급해 줄 것인가를 지정해 주어야합니다.
#
# * train / validation set 전용 generator를 별도로 정의합니다.
# * `batch_size`를 정의합니다 (128)
# * `target_size`를 정의합니다. (150 x 150). 이미지를 알아서 타겟 사이즈 만큼 잘라내어 공급합니다.
# * `class_mode`는 3개 이상의 클래스인 경우 'categorical' 이진 분류의 경우 `binary`를 지정합니다.
# * `subset`을 지정합니다. (training / validation)

# %%
# training_generator 생성 (subset='training')
training_generator = training_datagen.flow_from_directory(
    os.path.join('data/rps/'),
    target_size=(150, 150),
    batch_size=128,
    class_mode='sparse',
    subset='training'
)
# Out:
# Found 2016 images belonging to 3 classes.

# %%
# validation_generator 생성 (subset='validation')
validation_generator = training_datagen.flow_from_directory(
    os.path.join('data/rps/'),
    target_size=(150, 150),
    batch_size=128,
    class_mode='sparse',
    subset='validation'
)
# Out:
# Found 504 images belonging to 3 classes.

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# # STEP 3. 모델 정의 (Sequential)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.models import Sequential

# %%
model = Sequential([
    # Conv2D, MaxPooling2D 조합으로 층을 쌓습니다. 첫번째 입력층의 input_shape은 (150, 150, 3)으로 지정합니다.
    tf.keras.layers.Conv2D(64, 3, activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.Conv2D(64, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(2, 2), 
    tf.keras.layers.Conv2D(128, 3, activation='relu'),
    tf.keras.layers.Conv2D(128, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(2, 2), 
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.3), 
    tf.keras.layers.Dense(512, activation='relu' ), 
    tf.keras.layers.Dense(3, activation='softmax')   
    
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 146, 146, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 73, 73, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 69, 69, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 34, 34, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 147968)            0
#
#  dropout (Dropout)           (None, 147968)            0
#
#  dense (Dense)               (None, 512)               75760128
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 76,021,827
# Trainable params: 76,021,827
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# # STEP 4. 컴파일 (compile)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# # STEP 5. ModelCheckpoint 생성

# %%
# 코드를 실행하세요.
from tensorflow.keras.callbacks import ModelCheckpoint
checkpoint_path = "tmp_checkpoint.ckpt"
checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             save_weights_only=True, 
                             save_best_only=True, 
                             monitor='val_loss', 
                             verbose=1)

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# # STEP 6. 학습 (fit)

# %%
history = model.fit_generator(
      training_generator,
      steps_per_epoch=16,
      epochs=25,
      validation_data=validation_generator,
      validation_steps=3,
      verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/25
# 16/16 [==============================] - 39s 1s/step - loss: 2.3209 - accuracy: 0.3304 - val_loss: 1.1039 - val_accuracy: 0.5703
# Epoch 2/25
# 16/16 [==============================] - 20s 1s/step - loss: 1.0779 - accuracy: 0.4127 - val_loss: 1.1021 - val_accuracy: 0.2344
# Epoch 3/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.9951 - accuracy: 0.4886 - val_loss: 1.0291 - val_accuracy: 0.4141
# Epoch 4/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.8470 - accuracy: 0.6017 - val_loss: 0.9704 - val_accuracy: 0.5130
# Epoch 5/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.7594 - accuracy: 0.6453 - val_loss: 0.8345 - val_accuracy: 0.5443
# Epoch 6/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.5873 - accuracy: 0.7312 - val_loss: 0.8373 - val_accuracy: 0.7240
# Epoch 7/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.5629 - accuracy: 0.7510 - val_loss: 0.7674 - val_accuracy: 0.6380
# Epoch 8/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.4827 - accuracy: 0.7976 - val_loss: 0.8313 - val_accuracy: 0.6484
# Epoch 9/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.3541 - accuracy: 0.8566 - val_loss: 0.5160 - val_accuracy: 0.8438
# Epoch 10/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.3078 - accuracy: 0.8953 - val_loss: 0.6504 - val_accuracy: 0.8021
# Epoch 11/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.2794 - accuracy: 0.8983 - val_loss: 0.7873 - val_accuracy: 0.6198
# Epoch 12/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.2499 - accuracy: 0.9092 - val_loss: 0.8676 - val_accuracy: 0.6979
# Epoch 13/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.2352 - accuracy: 0.9147 - val_loss: 0.6392 - val_accuracy: 0.6979
# Epoch 14/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.1771 - accuracy: 0.9350 - val_loss: 0.7180 - val_accuracy: 0.7786
# Epoch 15/25
# 16/16 [==============================] - 20s 1s/step - loss: 0.1553 - accuracy: 0.9420 - val_loss: 0.6779 - val_accuracy: 0.7995
# Epoch 16/25
# 16/16 [==============================] - 20s 1s/step - loss: 0.1171 - accuracy: 0.9573 - val_loss: 1.0017 - val_accuracy: 0.7292
# Epoch 17/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.1053 - accuracy: 0.9668 - val_loss: 0.5813 - val_accuracy: 0.7786
# Epoch 18/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.1728 - accuracy: 0.9449 - val_loss: 0.5977 - val_accuracy: 0.7682
# Epoch 19/25
# 16/16 [==============================] - 20s 1s/step - loss: 0.1422 - accuracy: 0.9474 - val_loss: 0.6404 - val_accuracy: 0.7891
# Epoch 20/25
# 16/16 [==============================] - 20s 1s/step - loss: 0.1474 - accuracy: 0.9415 - val_loss: 0.6168 - val_accuracy: 0.8255
# Epoch 21/25
# 16/16 [==============================] - 20s 1s/step - loss: 0.0903 - accuracy: 0.9678 - val_loss: 0.7891 - val_accuracy: 0.7682
# Epoch 22/25
# 16/16 [==============================] - 20s 1s/step - loss: 0.0981 - accuracy: 0.9668 - val_loss: 0.7529 - val_accuracy: 0.7734
# Epoch 23/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.1062 - accuracy: 0.9673 - val_loss: 1.0091 - val_accuracy: 0.6536
# Epoch 24/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.1105 - accuracy: 0.9613 - val_loss: 0.6372 - val_accuracy: 0.7891
# Epoch 25/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0628 - accuracy: 0.9797 - val_loss: 0.7891 - val_accuracy: 0.7578

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# # STEP 7. 결과 확인

# %%
# Epoch 별 Loss와 Accuracy를 시각화하세요.
plt.figure(figsize = (16,6))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))

plt.subplot(1,2,1)
plt.plot(epochs, loss,  label='Train')
plt.plot(epochs, val_loss,  label='Valid')
plt.legend()
plt.title('Loss')

plt.subplot(1,2,2)
plt.plot(epochs, acc,  label='Train')
plt.plot(epochs, val_acc,  label='Valid')
plt.legend()
plt.title('Accuracy')

plt.show()

# %%
# 코드를 실행하세요. (label 정보)
indices = training_generator.class_indices
indices = {value : key for key, value in indices.items()}
indices
# Out:
# {0: 'paper', 1: 'rock', 2: 'scissors'}

# %%
# 코드를 실행하세요.
# step1의 subplot에서 title을 예측 결과로 설정하세요.
# 이미지 로드 후 shape를 (-1,150,150,3)으로 변경해야 model.predict 가 가능합니다.
from tensorflow.keras.preprocessing.image import load_img, img_to_array

plt.figure(figsize = (9,9))

for i, c in enumerate(['scissors', 'rock', 'paper']) :
    files = os.listdir(f'data/rps/{c}')[:3]
    for j, file in enumerate(files) :
        plt.subplot(3,3, 3*i + j + 1)

        # 이미지 로드
        image = load_img(f'data/rps/{c}/{file}', target_size=(150, 150))
        image = img_to_array(image) / 255
        
        # plot
        plt.imshow(image)
        plt.axis(False)
        plt.title(f'Predict : {indices[model.predict(image.reshape(-1,150,150,3)).argmax()]}')
plt.show()
